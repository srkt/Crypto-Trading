# %%
import requests
import json
import numpy as np
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# %%
pair = "BTC-XVG"
url = "https://bittrex.com/Api/v2.0/pub/market/GetTicks?marketName=" + pair +"&tickInterval=hour"
start = dt.datetime(2017,12,1)
end = dt.datetime(2018,1,19)

# %%
r = requests.get(url)

# %%
coin = pd.DataFrame(r.json()['result'])

# %%
# Only need closing data , so dropping Open,Low,High,BV
coin.drop(['O','L','H','BV'],inplace=True,axis=1)

# %%
coin.head()
# Out:
#               C                    T             V
# 0  7.100000e-07  2017-11-21T02:00:00  2.650472e+07
# 1  7.100000e-07  2017-11-21T03:00:00  2.784458e+07
# 2  7.100000e-07  2017-11-21T04:00:00  2.042004e+07
# 3  7.000000e-07  2017-11-21T05:00:00  1.007189e+07
# 4  7.000000e-07  2017-11-21T06:00:00  1.137366e+07

# %%
# Convert Time column frfilteredData Object to Timestamp
coin['T']=pd.to_datetime(coin['T'])

# %%
# Set index as T
coin.set_index('T')
coin.head()
# Out:
#               C                   T             V
# 0  7.100000e-07 2017-11-21 02:00:00  2.650472e+07
# 1  7.100000e-07 2017-11-21 03:00:00  2.784458e+07
# 2  7.100000e-07 2017-11-21 04:00:00  2.042004e+07
# 3  7.000000e-07 2017-11-21 05:00:00  1.007189e+07
# 4  7.000000e-07 2017-11-21 06:00:00  1.137366e+07

# %%
filteredData = pd.DataFrame()
filteredData = coin[coin['T']>start].copy()

# %%
filteredData.head(10)
# Out:
#                 C                   T             V
# 239  5.600000e-07 2017-12-01 01:00:00  3.364757e+06
# 240  5.600000e-07 2017-12-01 02:00:00  8.142881e+06
# 241  5.600000e-07 2017-12-01 03:00:00  4.610612e+06
# 242  5.500000e-07 2017-12-01 04:00:00  6.475530e+06
# 243  5.700000e-07 2017-12-01 05:00:00  1.392259e+07
# 244  5.800000e-07 2017-12-01 06:00:00  1.137024e+07
# 245  5.800000e-07 2017-12-01 07:00:00  1.351412e+07
# 246  5.700000e-07 2017-12-01 08:00:00  9.961239e+06
# 247  5.800000e-07 2017-12-01 09:00:00  1.540178e+07
# 248  5.700000e-07 2017-12-01 10:00:00  1.005270e+07

# %%
# filteredData['EMA9'] = filteredData['C'].rolling(9).mean()
# filteredData['EMA21'] = filteredData['C'].rolling(21).mean()

filteredData['EMA9'] = pd.ewma(filteredData['C'],span=9)
filteredData['EMA21'] = pd.ewma(filteredData['C'],span=21)
# Out:
# C:\Users\suman\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=9,min_periods=0,adjust=True,ignore_na=False).mean()
#   after removing the cwd from sys.path.
# C:\Users\suman\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: FutureWarning: pd.ewm_mean is deprecated for Series and will be removed in a future version, replace with
# 	Series.ewm(span=21,min_periods=0,adjust=True,ignore_na=False).mean()
#   """

# %%
plt.figure(figsize=(16,10))
plt.plot(filteredData['T'],filteredData['EMA9'])
plt.plot(filteredData['T'],filteredData['EMA21'])
plt.legend(['EMA9','EMA21'])
plt.figure(figsize=(16,4))
plt.plot(filteredData['T'],filteredData['V'])
# plt.legend(['Current Price','EMA9','EMA21'])
plt.show()

# %%
filteredData.head()
# Out:
#                 C                   T             V          EMA9  \
# 239  5.600000e-07 2017-12-01 01:00:00  3.364757e+06  5.600000e-07
# 240  5.600000e-07 2017-12-01 02:00:00  8.142881e+06  5.600000e-07
# 241  5.600000e-07 2017-12-01 03:00:00  4.610612e+06  5.600000e-07
# 242  5.500000e-07 2017-12-01 04:00:00  6.475530e+06  5.566125e-07
# 243  5.700000e-07 2017-12-01 05:00:00  1.392259e+07  5.605950e-07
#
#             EMA21
# 239  5.600000e-07
# 240  5.600000e-07
# 241  5.600000e-07
# 242  5.571321e-07
# 243  5.602180e-07

# %%
filteredData['BUY'] = np.where((filteredData['EMA9'] > filteredData['EMA21']) & (filteredData['EMA9'].shift(1) < filteredData['EMA21'].shift(1)),filteredData['C'],0)

# %%
filteredData['SELL'] = np.where((filteredData['EMA9'] < filteredData['EMA21']) & (filteredData['EMA9'].shift(1) > filteredData['EMA21'].shift(1)),filteredData['C'],0)

# %%
buysellDataframe = filteredData[(filteredData['BUY'] > 0) | (filteredData['SELL'] > 0)]
buysellDataframe.head(10)
# Out:
#                 C                   T             V          EMA9  \
# 243  5.700000e-07 2017-12-01 05:00:00  1.392259e+07  5.605950e-07
# 252  5.600000e-07 2017-12-01 14:00:00  1.523008e+07  5.692319e-07
# 260  5.700000e-07 2017-12-01 22:00:00  6.480219e+06  5.686875e-07
# 263  5.600000e-07 2017-12-02 01:00:00  1.207984e+07  5.673228e-07
# 285  5.600000e-07 2017-12-02 23:00:00  2.080411e+07  5.508929e-07
# 346  6.700000e-07 2017-12-05 12:00:00  1.572327e+07  6.788294e-07
# 425  5.300000e-07 2017-12-08 19:00:00  1.585837e+07  5.183131e-07
# 461  5.600000e-07 2017-12-10 07:00:00  1.124944e+07  5.672649e-07
# 491  5.400000e-07 2017-12-11 13:00:00  1.313775e+07  5.295828e-07
# 498  5.200000e-07 2017-12-11 20:00:00  1.919194e+07  5.317950e-07
#
#             EMA21           BUY          SELL
# 243  5.602180e-07  5.700000e-07  0.000000e+00
# 252  5.694316e-07  0.000000e+00  5.600000e-07
# 260  5.685487e-07  5.700000e-07  0.000000e+00
# 263  5.679448e-07  0.000000e+00  5.600000e-07
# 285  5.498729e-07  5.600000e-07  0.000000e+00
# 346  6.791286e-07  0.000000e+00  6.700000e-07
# 425  5.174237e-07  5.300000e-07  0.000000e+00
# 461  5.677667e-07  0.000000e+00  5.600000e-07
# 491  5.293740e-07  5.400000e-07  0.000000e+00
# 498  5.321537e-07  0.000000e+00  5.200000e-07

# %%
plt.figure(figsize=(16,10))
plt.plot(buysellDataframe['T'],buysellDataframe['C'])
plt.plot(buysellDataframe['T'],buysellDataframe['EMA9'])
plt.plot(buysellDataframe['T'],buysellDataframe['EMA21'])
plt.legend(['Current Price','EMA9','EMA21'])
plt.show()

# %%
#Dropping first row if it's a buy 
buysellDataframe.head()
# Out:
#                 C                   T             V          EMA9  \
# 243  5.700000e-07 2017-12-01 05:00:00  1.392259e+07  5.605950e-07
# 252  5.600000e-07 2017-12-01 14:00:00  1.523008e+07  5.692319e-07
# 260  5.700000e-07 2017-12-01 22:00:00  6.480219e+06  5.686875e-07
# 263  5.600000e-07 2017-12-02 01:00:00  1.207984e+07  5.673228e-07
# 285  5.600000e-07 2017-12-02 23:00:00  2.080411e+07  5.508929e-07
#
#             EMA21           BUY          SELL
# 243  5.602180e-07  5.700000e-07  0.000000e+00
# 252  5.694316e-07  0.000000e+00  5.600000e-07
# 260  5.685487e-07  5.700000e-07  0.000000e+00
# 263  5.679448e-07  0.000000e+00  5.600000e-07
# 285  5.498729e-07  5.600000e-07  0.000000e+00

# %%
# Backtesting...
BTC = 1
stocks = 0.0
print('Started with BTC :' + str(BTC))
for i,r in buysellDataframe.iterrows():
    
    if (r['BUY'] > 0.0) & (stocks == 0.0):
        stocks = BTC/r['BUY']
        print('Bought ' + pair + ' # ' + str(stocks) + ' on ' + str(r['T']))
    elif (r['SELL'] > 0.0) & (stocks > 0.0):
        BTC = stocks*r['SELL']
        stocks = 0.0
        print('Made ' + str(BTC) + ' BTC on ' + str(r['T']))
    

print('Final ' + pair + ' bought : #' + str(stocks))
print('Made BTC # :' + str(BTC))
# Out:
# Started with BTC :1
# Bought BTC-XVG # 1754385.9649122804 on 2017-12-01 05:00:00
# Made 0.9824561403508771 BTC on 2017-12-01 14:00:00
# Bought BTC-XVG # 1723607.2637734686 on 2017-12-01 22:00:00
# Made 0.9652200677131425 BTC on 2017-12-02 01:00:00
# Bought BTC-XVG # 1723607.2637734686 on 2017-12-02 23:00:00
# Made 1.154816866728224 BTC on 2017-12-05 12:00:00
# Bought BTC-XVG # 2178899.7485438185 on 2017-12-08 19:00:00
# Made 1.2201838591845384 BTC on 2017-12-10 07:00:00
# Bought BTC-XVG # 2259599.7392306267 on 2017-12-11 13:00:00
# Made 1.174991864399926 BTC on 2017-12-11 20:00:00
# Bought BTC-XVG # 2175910.859999863 on 2017-12-12 04:00:00
# Made 1.10971453859993 BTC on 2017-12-12 16:00:00
# Bought BTC-XVG # 1981633.104642732 on 2017-12-13 00:00:00
# Made 1.862735118364168 BTC on 2017-12-15 09:00:00
# Bought BTC-XVG # 1633978.174003656 on 2017-12-15 15:00:00
# Made 4.591478668950273 BTC on 2017-12-18 14:00:00
# Bought BTC-XVG # 1439335.0059405246 on 2017-12-18 19:00:00
# Made 10.435178793068804 BTC on 2017-12-21 14:00:00
# Bought BTC-XVG # 1275694.2289815166 on 2017-12-21 23:00:00
# Made 9.746303909418787 BTC on 2017-12-22 01:00:00
# Bought BTC-XVG # 1085334.5110711344 on 2017-12-22 20:00:00
# Made 18.114232989777232 BTC on 2017-12-25 07:00:00
# Bought BTC-XVG # 1517104.9405173562 on 2017-12-27 01:00:00
# Made 17.143285827846125 BTC on 2017-12-27 03:00:00
# Bought BTC-XVG # 1529285.087229806 on 2017-12-28 20:00:00
# Made 15.598707889744022 BTC on 2017-12-30 06:00:00
# Bought BTC-XVG # 1375547.4329580266 on 2017-12-30 14:00:00
# Made 18.04718232040931 BTC on 2018-01-01 06:00:00
# Bought BTC-XVG # 1691394.7816691012 on 2018-01-04 05:00:00
# Made 17.624333624992033 BTC on 2018-01-05 10:00:00
# Bought BTC-XVG # 1616911.3417423882 on 2018-01-06 09:00:00
# Made 16.96139997487765 BTC on 2018-01-06 18:00:00
# Bought BTC-XVG # 1503670.2105387987 on 2018-01-07 02:00:00
# Made 15.968977635922043 BTC on 2018-01-07 19:00:00
# Bought BTC-XVG # 1466389.1309386631 on 2018-01-07 21:00:00
# Made 19.561631006721765 BTC on 2018-01-09 23:00:00
# Bought BTC-XVG # 1743460.8740393731 on 2018-01-12 10:00:00
# Made 19.61393483294295 BTC on 2018-01-13 06:00:00
# Bought BTC-XVG # 2291347.5272129616 on 2018-01-17 21:00:00
# Made 21.42409937944119 BTC on 2018-01-19 14:00:00
# Final BTC-XVG bought : #0.0
# Made BTC # :21.42409937944119
